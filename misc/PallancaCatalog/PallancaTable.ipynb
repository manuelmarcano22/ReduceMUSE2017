# %%
import camelot

# %%
tables = camelot.read_pdf('Pallanca.pdf',pages='7', flavor='stream',strip_text='∗',row_tol=5)

# %%
tables[0].df
# Out:
#        0            1            2      3      4                        5   \
# 0                                                  Hα emitters in NGC 6397
# 1      ID           RA          Dec     V0     I0                      Hα0
# 2                J2000        J2000
# 3     CV1  265.1733338  -53.6720091  17.91  17.07                    16.51
# 4
# 5
# 6     CV2  265.1762738  -53.6746139  19.14  18.07                    17.64
# 7     CV3  265.1777106  -53.6720105  17.83  17.46                    16.73
# 8     CV4  265.1742981  -53.6725857  19.70  18.65                    17.26
# 9     CV5  265.1737722  -53.6747031  20.68  19.62                    18.26
# 10    CV6  265.2040901  -53.6634800  19.27  18.33                    18.01
# 11    CV7  265.1907295  -53.6782007  23.78  22.94                    22.23
# 12  MSP-A  265.1859047  -53.6782108  16.43  15.68                    15.66
# 13
# 14   MSP?  265.1775326  -53.6743174  16.05  15.12                    15.11
# 15
# ...

# %%
info = [(i[0],float(i[1]),float(i[2])) for i in tables[0].data[3:] if i[0] != '']

# %%
#region to plot
findreg = 'Pallanca.reg'


with open(findreg,'w') as fileone:
    for name,ra,dec in info:
        #print(name,ra,dec)
        text='fk5; circle({0},{1},.1") # color=blue text={2} \n'.format(ra,dec,'{'+str(name)+"}")
        #text='fk5; circle({0},{1},.1") # color=red text=\{{2}\}\n'.format(ra[index],dec[index],index)
        fileone.write(text)
        #print(text)
