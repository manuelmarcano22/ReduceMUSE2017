# %%
from search import getlatloglist, getspectrafromregion, findlines, makeregionfromlist
from spectral_cube import SpectralCube

import aplpy



from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
cube = '../../Observation1/data/FixedAstrometryDATACUBE_FINAL.fits'
#cube = 'FixedAstrometryDATACUBE_FINAL.fits'
#cube = 'cubenoedges.fits'
spectralcube= SpectralCube.read(cube,hdu=1)

# %%
U97 = getspectrafromregion(spectralcube,ra='17:40:43.9543', dec='-53:40:07.464', aperture=0.374,name='U97',xmin=4750.,xmax=9350.,
                                      exclude=[6520,6600])
U97.plot()
# Out:
#   <div class="bk-root" id="670e6537-43ea-46f5-beb7-1aba7bdb22e0" data-root-id="1002"></div>
# Figure(id='1002', ...)

# %%
U97.plot()
# Out:
#   <div class="bk-root" id="c3212d8f-4703-4029-bf89-85b08130aa38" data-root-id="1003"></div>
# Figure(id='1003', ...)
