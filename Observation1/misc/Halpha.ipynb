# %%
import astropy.units as u
from astropy.io import fits
from spectral_cube import SpectralCube
from spectral_cube import BooleanArrayMask
import matplotlib.pyplot as plt
from bokeh.plotting import output_notebook, figure, show

output_notebook()
# %matplotlib widget
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1099">Loading BokehJS ...</span>
#     </div>

# %%
cube1= SpectralCube.read('../data/DATACUBE_FINAL.fits',hdu=1)
# Out:
# WARNING: UnitsWarning: '10**(-20)*erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
halpha = cube1.spectral_slab(6550*u.angstrom, 6560*u.angstrom).median(axis=0)
halpha.quicklook()
# Out:
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# INFO: Auto-setting vmin to -6.089e+03 [aplpy.core]
# INFO: Auto-setting vmax to  6.840e+04 [aplpy.core]

# %%
todos = cube1.spectral_slab(6400*u.angstrom, 6500*u.angstrom).mean(axis=0)
resta = halpha - todos
#resta.write('restaHalpha2.fits')
resta.quicklook()
lmc =resta.FITSFigure
#lmc.set_tick_labels_format(xformat='hh:mm:ss',yformat='dd:mm:ss')
lmc.show_grayscale(invert=True)
#lmc.show_colorscale(cmap='grayscale')
lmc.add_grid()
#lmc.tick_labels.set_xformat('ddd.dddd')
#lmc.tick_labels.set_yformat('ddd.dddd')

#lmc.show_grayscale(stretch='arcsinh',invert=True)
#lmc.show_grayscale(stretch='arcsinh', vmin=1, vmax=10,invert=True)
#lmc.show_grid()
#lmc.set_grid_alpha(0.2)
#lmc.set_grid_color('black')
#lmc.set_axis_labels_size('18')
#lmc.set_tick_labels_size('16')
#lmc.set_tick_color('black')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f352c0856a8>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
# INFO: Auto-setting vmin to -4.879e+03 [aplpy.core]
# INFO: Auto-setting vmax to  8.451e+02 [aplpy.core]
# INFO: Auto-setting vmin to -8.278e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.076e+03 [aplpy.core]

# %%
#resta.write('restaHalpha.fits')

# %% [markdown]
#  # Plot spectra from region

# %%
ds9_str = 'fk5; circle(17:40:41.0354,-53:40:16.824,0.4")' 
subcube = cube1.subcube_from_ds9region(ds9_str)  
spectrum = subcube.mean(axis=(1, 2)) 

# create a new plot
p = figure(plot_width=1000, plot_height=500, title="U")

# add some renderers
p.line(cube1.spectral_axis,spectrum)
show(p)
# Out:
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/masks.py:632: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return LazyMask(self._function, data=self._data[view],
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:1222: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return self._new_cube_with(data=self._data[view],
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f352c0856a8>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
#   <div class="bk-root" id="83e3bce0-5c66-49b5-beb4-14070e952755" data-root-id="1003"></div>

# %% [markdown]
# # With short you can see U18 cearly

# %%
halpha = cube1.spectral_slab(6560*u.angstrom, 6570*u.angstrom).median(axis=0)




todos = cube1.spectral_slab(6500*u.angstrom, 6600*u.angstrom).mean(axis=0)
resta = halpha - todos
#resta.write('restaHalpha2.fits')
resta.quicklook()
lmc =resta.FITSFigure
#lmc.set_tick_labels_format(xformat='hh:mm:ss',yformat='dd:mm:ss')
lmc.show_grayscale(invert=False)
#lmc.show_colorscale(cmap='grayscale')
lmc.add_grid()
#lmc.tick_labels.set_xformat('ddd.dddd')
#lmc.tick_labels.set_yformat('ddd.dddd')

#lmc.show_grayscale(stretch='arcsinh',invert=True)
#lmc.show_grayscale(stretch='arcsinh', vmin=1, vmax=10,invert=True)
#lmc.show_grid()
#lmc.set_grid_alpha(0.2)
#lmc.set_grid_color('black')
#lmc.set_axis_labels_size('18')
#lmc.set_tick_labels_size('16')
#lmc.set_tick_color('black')
# Out:
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f352c0856a8>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
# INFO: Auto-setting vmin to -4.700e+03 [aplpy.core]
# INFO: Auto-setting vmax to  4.902e+02 [aplpy.core]
# INFO: Auto-setting vmin to -5.850e+03 [aplpy.core]
# INFO: Auto-setting vmax to  6.039e+02 [aplpy.core]

# %% [markdown]
# # Helium try

# %%
he5875 = cube1.spectral_slab(5870*u.angstrom, 5880*u.angstrom).mean(axis=0)




todos = cube1.spectral_slab(6000*u.angstrom, 6200*u.angstrom).mean(axis=0)
resta = he5875 - todos
#resta.write('restaHalpha2.fits')
resta.quicklook()
lmc =resta.FITSFigure
#lmc.set_tick_labels_format(xformat='hh:mm:ss',yformat='dd:mm:ss')
lmc.show_grayscale(invert=False)
#lmc.show_colorscale(cmap='grayscale')
lmc.add_grid()
#lmc.tick_labels.set_xformat('ddd.dddd')
#lmc.tick_labels.set_yformat('ddd.dddd')

#lmc.show_grayscale(stretch='arcsinh',invert=True)
#lmc.show_grayscale(stretch='arcsinh', vmin=1, vmax=10,invert=True)
#lmc.show_grid()
#lmc.set_grid_alpha(0.2)
#lmc.set_grid_color('black')
#lmc.set_axis_labels_size('18')
#lmc.set_tick_labels_size('16')
#lmc.set_tick_color('black')

#resta.write('restaHeI6678.fits')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f352c0856a8>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f352c0856a8>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/envs/musengc6397/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
# FigureCanvasNbAgg()
# INFO: Auto-setting vmin to -1.440e+03 [aplpy.core]
# INFO: Auto-setting vmax to  3.086e+03 [aplpy.core]
# INFO: Auto-setting vmin to -1.307e+03 [aplpy.core]
# INFO: Auto-setting vmax to  2.071e+03 [aplpy.core]
